# %% [markdown]
# # 01 Extraction - Loading the Data
#
# In this notebook, we are just going to load our dataset and see what's inside. We need to make sure the data is there and looks okay before we start cleaning it.

# %%
import pandas as pd

# Setting the path to our file
# Since we are in the 'notebooks' folder, we go up one level then into 'data/raw'
file_path = "../data/raw/APY.csv"

print("Loading the file from:", file_path)

# %% [markdown]
# ## Loading the dataset

# %%
# Reading the CSV file using pandas
df = pd.read_csv(file_path)

# Showing the first 5 rows to see what it looks like
df.head()

# %% [markdown]
# ## Looking at the columns and data types

# %%
print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))

# Using df.info() to see data types and if there are null values
df.info()

# %% [markdown]
# ## Checking for missing values
#
# I want to see which columns have nulls so I know what to fix later.

# %%
print("Missing values per column:")
df.isnull().sum()

# %% [markdown]
# ## Summary stats
#
# Just to see the average and max values for each column.

# %%
df.describe()

# %% [markdown]
# ## Conclusion for now
#
# The data loaded fine! I see some missing values in the Production column and some spaces in the column names. I'll fix these in the next notebook.
